# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/kaggle/input/pgprnon-pgpr/pgpr_non_pgpr_clean.csv')

# %%
df.shape
# Out:
# (86446, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86446 entries, 0 to 86445
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         86446 non-null  int64
#  1   Orientation        86446 non-null  object
#  2   Protein accession  86446 non-null  object
#  3   Protein name       86446 non-null  object
#  4   Protein length     86446 non-null  float64
#  5   DNA_sequence       86446 non-null  object
#  6   Target             86446 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 4.6+ MB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# Orientation          0
# Protein accession    0
# Protein name         0
# Protein length       0
# DNA_sequence         0
# Target               0
# dtype: int64

# %%
df = df.drop(columns=['Unnamed: 0', 'Protein accession', 'DNA_sequence'], axis= 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86446 entries, 0 to 86445
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Orientation     86446 non-null  object
#  1   Protein name    86446 non-null  object
#  2   Protein length  86446 non-null  float64
#  3   Target          86446 non-null  float64
# dtypes: float64(2), object(2)
# memory usage: 2.6+ MB

# %%
df['Protein name'].nunique()
# Out:
# 14048

# %%
df.Target.unique()
# Out:
# array([1., 0.])

# %%
# Veri setindeki yinelenen gözlemleri kontrol eder ve bunları kaldırır

def duplicate_values(df):
    print("Duplicate check...")
    num_duplicates = df.duplicated(subset=None, keep='first').sum()
    if num_duplicates > 0:
        print("There are", num_duplicates, "duplicated observations in the dataset.")
        df.drop_duplicates(keep='first', inplace=True)
        print(num_duplicates, "duplicates were dropped!")
        print("No more duplicate rows!")
    else:
        print("There are no duplicated observations in the dataset.")

# %%
#duplicate_values(df)

# %%
X = df.drop('Target',axis=1)
y = df['Target']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=11)

# %%
ohe = X_train.select_dtypes("object").columns
num = X_train.select_dtypes("float64").columns

# %%
num
# Out:
# Index(['Protein length'], dtype='object')

# %%
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.preprocessing import StandardScaler

ohe_enc = OneHotEncoder(handle_unknown='ignore') #OneHotEncoder
std_sca = StandardScaler()
column_trans = make_column_transformer((ohe_enc, ohe),(std_sca, num), remainder='passthrough')

# %%
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier

operations = [("OneHotEncoder", column_trans),
              ("RF_model", RandomForestClassifier(random_state=11))]

pipe_model = Pipeline(steps=operations)

pipe_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('OneHotEncoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   Index(['Orientation', 'Protein name'], dtype='object')),
#                                                  ('standardscaler',
#                                                   StandardScaler(),
#                                                   Index(['Protein length'], dtype='object'))])),
#                 ('RF_model', RandomForestClassifier(random_state=11))])

# %%
from sklearn.metrics import accuracy_score,precision_recall_fscore_support

# %%
def calculate_results(y_true, y_pred):
    model_accuracy = accuracy_score(y_true, y_pred)
    model_precision, model_recall, model_f1,_ = precision_recall_fscore_support(y_true, y_pred,average="weighted")
    model_results = {"accuracy":model_accuracy,
                     "precision":model_precision,
                     "recall" :model_recall,
                     "f1":model_f1}
    return model_results

# %%
calculate_results(y_true=y_test,
                  y_pred=(pipe_model.predict(X_test)))
# Out:
# {'accuracy': 0.6910931174089069,
#  'precision': 0.6917918484995064,
#  'recall': 0.6910931174089069,
#  'f1': 0.6908134549492512}

# %%
column_trans.get_feature_names_out()
# Out:
# array(['onehotencoder__Orientation_minus',
#        'onehotencoder__Orientation_plus',
#        'onehotencoder__Protein name_(2,3-dihydroxybenzoyl)adenylate synthase',
#        ...,
#        'onehotencoder__Protein name_zincin-like metallopeptidase domain-containing protein',
#        'onehotencoder__Protein name_zonular occludens toxin domain-containing protein',
#        'standardscaler__Protein length'], dtype=object)

# %%
pipe_model["RF_model"].feature_importances_
# Out:
# array([8.61534571e-04, 6.77444891e-04, 3.25929779e-05, ...,
#        5.49067620e-05, 1.99193182e-05, 3.20117965e-01])

# %%
features = pipe_model["OneHotEncoder"].get_feature_names_out()
features
# Out:
# array(['onehotencoder__Orientation_minus',
#        'onehotencoder__Orientation_plus',
#        'onehotencoder__Protein name_(2,3-dihydroxybenzoyl)adenylate synthase',
#        ...,
#        'onehotencoder__Protein name_zincin-like metallopeptidase domain-containing protein',
#        'onehotencoder__Protein name_zonular occludens toxin domain-containing protein',
#        'standardscaler__Protein length'], dtype=object)

# %%
new_features = [i.replace("onehotencoder__","").replace("remainder__", "") for i in features]
new_features
# Out:
# ['Orientation_minus',
#  'Orientation_plus',
#  'Protein name_(2,3-dihydroxybenzoyl)adenylate synthase',
#  'Protein name_(2,3-dihydroxybenzoyl)adenylate synthase EntE',
#  'Protein name_(2E,6E)-farnesyl diphosphate synthase',
#  'Protein name_(2E,6E)-farnesyl-diphosphate-specific ditrans,polycis-undecaprenyl-diphosphate synthase',
#  'Protein name_(2Fe-2S)-binding protein',
#  'Protein name_(3,5-dihydroxyphenyl)acetyl-CoA 1,2-dioxygenase DpgC',
#  'Protein name_(3R)-hydroxymyristoyl-ACP dehydratase',
#  'Protein name_(4S)-4-hydroxy-5-phosphonooxypentane-2,3-dione isomerase',
#  'Protein name_(E)-4-hydroxy-3-methylbut-2-enyl-diphosphate synthase (flavodoxin)',
#  'Protein name_(Fe-S)-binding protein',
#  'Protein name_(Na+)-NQR maturation NqrM',
#  'Protein name_(S)-acetoin forming diacetyl reductase',
#  'Protein name_(S)-benzoin forming benzil reductase',
#  'Protein name_(S)-ureidoglycine aminohydrolase',
#  'Protein name_(d)CMP kinase',
#  'Protein name_(dimethylallyl)adenosine tRNA methylthiotransferase',
#  'Protein name_1,2-phenylacetyl-CoA epoxidase subunit A',
#  'Protein name_1,2-phenylacetyl-CoA epoxidase subunit B',
#  'Protein name_1,2-phenylacetyl-CoA epoxidase subunit PaaA',
#  'Protein name_1,2-phenylacetyl-CoA epoxidase subunit PaaB',
#  'Protein name_1,2-phenylacetyl-CoA epoxidase subunit PaaC',
#  'Protein name_1,2-phenylacetyl-CoA epoxidase subunit PaaD',
#  'Protein name_1,2-phenylacetyl-CoA epoxidase subunit PaaE',
#  'Protein name_1,3-propanediol dehydrogenase',
#  'Protein name_1,4-alpha-glucan branching enzyme',
#  'Protein name_1,4-alpha-glucan branching protein',
#  'Protein name_1,4-alpha-glucan branching protein GlgB',
#  'Protein name_1,4-dihydroxy-2-naphthoate octaprenyltransferase',
#  'Protein name_1,4-dihydroxy-2-naphthoate polyprenyltransferase',
#  'Protein name_1,4-dihydroxy-2-naphthoyl-CoA hydrolase',
#  'Protein name_1,4-dihydroxy-2-naphthoyl-CoA synthase',
#  'Protein name_1,4-dihydroxy-6-naphthoate synthase',
#  'Protein name_1,6-anhydro-N-acetylmuramoyl-L-alanine amidase',
#  'Protein name_1,6-anhydro-N-acetylmuramyl-L-alanine amidase AmpD',
#  'Protein name_1,6-dihydroxycyclohexa-2,4-diene-1-carboxylate dehydrogenase',
#  'Protein name_1-(5-phosphoribosyl)-5-[(5-phosphoribosylamino)methylideneamino]imidazole-4-carboxamide isomerase',
#  'Protein name_1-acyl-sn-glycerol-3-phosphate acyltransferase',
#  'Protein name_1-acyl-sn-glycerol-3-phosphate acyltransferase domain-containing protein',
#  'Protein name_1-acylglycerol-3-phosphate O-acyltransferase',
#  'Protein name_1-acylglycerol-3-phosphate O-acyltransferase YihG',
#  'Protein name_1-deoxy-11-beta-hydroxypentalenate dehydrogenase',
#  'Protein name_1-deoxy-D-xylulose 5-phosphate:thiol sulfurtransferase',
#  'Protein name_1-deoxy-D-xylulose-5-phosphate reductoisomerase',
#  'Protein name_1-deoxy-D-xylulose-5-phosphate synthase',
#  'Protein name_1-deoxyxylulose-5-phosphate synthase YajO',
#  'Protein name_1-hydroxy-2-methyl-2-butenyl 4-diphosphate reductase',
#  'Protein name_1-phosphatidylinositol phosphodiesterase',
#  'Protein name_1-phosphofructokinase',
#  'Protein name_1-phosphofructokinase family hexose kinase',
#  'Protein name_1-propanol dehydrogenase PduQ',
#  'Protein name_1-pyrroline-5-carboxylate dehydrogenase',
#  'Protein name_10-formyltetrahydrofolate:L-methionyl-tRNA(fMet) N-formyltransferase',
#  'Protein name_16S rRNA (adenine(1518)-N(6)/adenine(1519)-N(6))-dimethyltransferase RsmA',
#  "Protein name_16S rRNA (cytidine(1402)-2'-O)-methyltransferase",
#  'Protein name_16S rRNA (cytosine(1402)-N(4))-methyltransferase',
#  'Protein name_16S rRNA (cytosine(1402)-N(4))-methyltransferase RsmH',
#  'Protein name_16S rRNA (cytosine(1407)-C(5))-methyltransferase RsmF',
#  'Protein name_16S rRNA (cytosine(967)-C(5))-methyltransferase',
#  'Protein name_16S rRNA (cytosine(967)-C(5))-methyltransferase RsmB',
#  'Protein name_16S rRNA (guanine(1207)-N(2))-methyltransferase RsmC',
#  'Protein name_16S rRNA (guanine(1516)-N(2))-methyltransferase RsmJ',
#  'Protein name_16S rRNA (guanine(527)-N(7))-methyltransferase RsmG',
#  'Protein name_16S rRNA (guanine(966)-N(2))-methyltransferase',
#  'Protein name_16S rRNA (guanine(966)-N(2))-methyltransferase RsmD',
#  'Protein name_16S rRNA (uracil(1498)-N(3))-methyltransferase',
#  "Protein name_16S rRNA 2'-O-ribose C1402 methyltransferase",
#  'Protein name_16S rRNA m(2)G1207 methyltransferase',
#  'Protein name_16S rRNA m(2)G1516 methyltransferase',
#  'Protein name_16S rRNA m(4)C1402 methyltransferase',
#  'Protein name_16S rRNA m(5)C1407 methyltransferase',
#  'Protein name_16S rRNA m(6)2A1518,m(6)2A1519 dimethyltransferase',
#  'Protein name_16S rRNA m(7)G527 methyltransferase',
#  'Protein name_16S rRNA pseudouridine(516) synthase',
#  'Protein name_16S rRNA pseudouridine(516) synthase RsuA',
#  'Protein name_16S rRNA-processing protein RimM',
#  "Protein name_2',3'-cyclic-nucleotide 2'-phosphodiesterase",
#  "Protein name_2'-5' RNA ligase family protein",
#  "Protein name_2'-O-acetyl-ADP-ribose deacetylase, regulator of RNase III activity",
#  'Protein name_2,3,4,5-tetrahydropyridine-2,6-dicarboxylate N-acetyltransferase',
#  'Protein name_2,3,4,5-tetrahydropyridine-2,6-dicarboxylate N-succinyltransferase',
#  'Protein name_2,3-bisphosphoglycerate-dependent phosphoglycerate mutase',
#  'Protein name_2,3-bisphosphoglycerate-independent phosphoglycerate mutase',
#  'Protein name_2,3-butanediol dehydrogenase',
#  'Protein name_2,3-dehydroadipyl-CoA hydratase PaaF',
#  'Protein name_2,3-diaminopropionate ammonia-lyase',
#  'Protein name_2,3-diaminopropionate biosynthesis protein SbnA',
#  'Protein name_2,3-diaminopropionate biosynthesis protein SbnB',
#  'Protein name_2,3-dihydro-2,3-dihydroxybenzoate dehydrogenase',
#  'Protein name_2,3-dihydro-2,3-dihydroxybenzoate dehydrogenase EntA',
#  'Protein name_2,3-dihydroxy-2,3-dihydrophenylpropionate dehydrogenase',
#  'Protein name_2,3-dihydroxybenzoate-AMP ligase',
#  'Protein name_2,3-dihydroxyphenylpropionate/2,3-dihydroxicinnamic acid 1,2-dioxygenase',
#  'Protein name_2,3-diketo-5-methylthiopentyl-1-phosphate enolase',
#  'Protein name_2,3-diketo-L-gulonate:Na(+) symporter - membrane subunit',
#  'Protein name_2,3-diphosphoglycerate-dependent phosphoglycerate mutase',
#  'Protein name_2,3-diphosphoglycerate-dependent phosphoglycerate mutase GpmB',
#  'Protein name_2,4-dienoyl-CoA reductase',
#  'Protein name_2,5-didehydrogluconate reductase DkgA',
#  'Protein name_2,5-didehydrogluconate reductase DkgB',
#  'Protein name_2,5-dihydroxypyridine 5,6-dioxygenase',
#  'Protein name_2,7-anhydro-N-acetylneuraminate hydratase',
#  'Protein name_2-(1,2-epoxy-1,2-dihydrophenyl)acetyl-CoA isomerase PaaG',
#  'Protein name_2-C-methyl-D-erythritol 2,4-cyclodiphosphate synthase',
#  'Protein name_2-C-methyl-D-erythritol 4-phosphate cytidylyltransferase',
#  'Protein name_2-Cys peroxiredoxin',
#  'Protein name_2-O-alpha-mannosyl-D-glycerate specific PTS enzyme II',
#  'Protein name_2-alkyl-3-oxoalkanoate reductase',
#  'Protein name_2-amino-3-ketobutyrate CoA ligase',
#  'Protein name_2-amino-4-hydroxy-6-hydroxymethyldihydropteridine diphosphokinase',
#  'Protein name_2-amino-4-hydroxy-6-hydroxymethyldihydropteridine pyrophosphokinase',
#  'Protein name_2-aminoethylphosphonate ABC transporter permease subunit',
#  'Protein name_2-aminoethylphosphonate ABC transporter substrate-binding protein',
#  'Protein name_2-aminoethylphosphonate--pyruvate transaminase',
#  'Protein name_2-dehydro-3-deoxy-6-phosphogalactonate aldolase',
#  'Protein name_2-dehydro-3-deoxy-D-gluconate 5-dehydrogenase KduD',
#  'Protein name_2-dehydro-3-deoxy-D-gluconate:H(+) symporter',
#  'Protein name_2-dehydro-3-deoxygalactonokinase',
#  'Protein name_2-dehydro-3-deoxyglucarate aldolase',
#  'Protein name_2-dehydro-3-deoxygluconokinase',
#  'Protein name_2-dehydropantoate 2-reductase',
#  'Protein name_2-deoxyribose-5-phosphate aldolase',
#  'Protein name_2-hydroxy-3-keto-5-methylthiopentenyl-1-phosphate phosphatase',
#  'Protein name_2-hydroxy-3-oxopropionate reductase',
#  'Protein name_2-hydroxy-6-ketonona-2,4-dienedioate hydrolase',
#  'Protein name_2-hydroxy-6-oxonona-2,4-dienedioate hydrolase',
#  'Protein name_2-hydroxyacid dehydrogenase',
#  'Protein name_2-hydroxyacyl-CoA dehydratase',
#  'Protein name_2-hydroxyacyl-CoA dehydratase family protein',
#  'Protein name_2-hydroxyacyl-CoA dehydratase subunit D',
#  'Protein name_2-hydroxycarboxylate transporter family protein',
#  'Protein name_2-hydroxychromene-2-carboxylate isomerase',
#  'Protein name_2-hydroxycyclohepta-1,4,6-triene-1-carboxyl-CoA thioesterase',
#  'Protein name_2-hydroxymuconate tautomerase',
#  'Protein name_2-iminoacetate synthase',
#  'Protein name_2-iminoacetate synthase ThiH',
#  'Protein name_2-iminobutanoate/2-iminopropanoate deaminase',
#  'Protein name_2-isopropylmalate synthase',
#  'Protein name_2-keto-3-deoxy-L-rhamnonate aldolase',
#  'Protein name_2-keto-3-deoxygluconate permease',
#  'Protein name_2-keto-3-deoxygluconate transporter',
#  'Protein name_2-keto-4-pentenoate hydratase',
#  'Protein name_2-ketobutyrate formate-lyase/pyruvate formate-lyase 4',
#  'Protein name_2-methylcitrate dehydratase',
#  'Protein name_2-methylcitrate synthase',
#  'Protein name_2-methylisocitrate lyase',
#  'Protein name_2-nitroimidazole exporter',
#  'Protein name_2-octaprenyl-6-methoxyphenol 4-hydroxylase',
#  'Protein name_2-octaprenyl-6-methoxyphenyl hydroxylase',
#  'Protein name_2-oxo acid dehydrogenase subunit E2',
#  'Protein name_2-oxo-4-hydroxy-4-carboxy-5-ureidoimidazoline decarboxylase',
#  'Protein name_2-oxo-hepta-3-ene-1,7-dioic acid hydratase',
#  'Protein name_2-oxo-tetronate isomerase',
#  'Protein name_2-oxoacid:acceptor oxidoreductase family protein',
#  'Protein name_2-oxoacid:acceptor oxidoreductase subunit alpha',
#  'Protein name_2-oxoacid:ferredoxin oxidoreductase subunit beta',
#  'Protein name_2-oxoglutarate and iron-dependent oxygenase domain-containing protein',
#  'Protein name_2-oxoglutarate dehydrogenase E1 component',
#  'Protein name_2-oxoglutarate dehydrogenase complex dihydrolipoyllysine-residue succinyltransferase',
#  'Protein name_2-oxoglutarate dehydrogenase, E2 component, dihydrolipoamide succinyltransferase',
#  'Protein name_2-oxoglutarate ferredoxin oxidoreductase subunit beta',
#  'Protein name_2-oxoisovalerate dehydrogenase, E1 component subunit alpha',
#  'Protein name_2-oxoisovalerate dehydrogenase, E2 component, dihydrolipoamide acetyltransferase',
#  'Protein name_2-phospho-L-lactate guanylyltransferase',
#  'Protein name_2-phospho-L-lactate transferase',
#  'Protein name_2-phosphosulfolactate phosphatase',
#  'Protein name_2-polyprenyl-3-methyl-6-methoxy-1,4-benzoquinone monooxygenase',
#  'Protein name_2-polyprenylphenol 6-hydroxylase',
#  'Protein name_2-succinyl-5-enolpyruvyl-6-hydroxy-3-cyclohexene-1-carboxylic-acid synthase',
#  'Protein name_2-succinyl-6-hydroxy-2,4-cyclohexadiene-1-carboxylate synthase',
#  'Protein name_2-succinyl-6-hydroxy-2,4-cyclohexadiene-1-carboxylic acid synthase/2-oxoglutarate decarboxylase',
#  'Protein name_2-succinylbenzoate-CoA ligase',
#  'Protein name_23S rRNA (adenine(1618)-N(6))-methyltransferase RlmF',
#  'Protein name_23S rRNA (adenine(2030)-N(6))-methyltransferase RlmJ',
#  'Protein name_23S rRNA (adenine(2503)-C(2))-methyltransferase RlmN',
#  "Protein name_23S rRNA (cytidine(2498)-2'-O)-methyltransferase RlmM",
#  'Protein name_23S rRNA (cytosine(1962)-C(5))-methyltransferase RlmI',
#  'Protein name_23S rRNA (guanine(1835)-N(2))-methyltransferase RlmG',
#  'Protein name_23S rRNA (guanine(745)-N(1))-methyltransferase',
#  "Protein name_23S rRNA (guanosine(2251)-2'-O)-methyltransferase RlmB",
#  'Protein name_23S rRNA (pseudouridine(1915)-N(3))-methyltransferase RlmH',
#  'Protein name_23S rRNA (uracil(1939)-C(5))-methyltransferase RlmD',
#  'Protein name_23S rRNA (uracil(747)-C(5))-methyltransferase RlmC',
#  "Protein name_23S rRNA (uridine(2552)-2'-O)-methyltransferase RlmE",
#  "Protein name_23S rRNA 2'-O-ribose G2251 methyltransferase",
#  "Protein name_23S rRNA 2'-O-ribose U2552 methyltransferase",
#  'Protein name_23S rRNA 5-hydroxycytidine C2501 synthase',
#  'Protein name_23S rRNA accumulation protein YceD',
#  'Protein name_23S rRNA m(2)A2503 methyltransferase/tRNA m(2)A37 methyltransferase',
#  'Protein name_23S rRNA m(2)G1835 methyltransferase',
#  'Protein name_23S rRNA m(3)psi1915 methyltransferase',
#  'Protein name_23S rRNA m(5)C1962 methyltransferase',
#  'Protein name_23S rRNA m(5)U1939 methyltransferase',
#  'Protein name_23S rRNA m(5)U747 methyltransferase',
#  'Protein name_23S rRNA m(6)A2030 methyltransferase',
#  'Protein name_23S rRNA pseudouridine(1911/1915/1917) synthase',
#  'Protein name_23S rRNA pseudouridine(1911/1915/1917) synthase RluD',
#  'Protein name_23S rRNA pseudouridine(2457) synthase',
#  'Protein name_23S rRNA pseudouridine(2457) synthase RluE',
#  'Protein name_23S rRNA pseudouridine(2604) and tRNA(Tyr) pseudouridine(35) synthase',
#  'Protein name_23S rRNA pseudouridine(2604) synthase RluF',
#  'Protein name_23S rRNA pseudouridine(2605) synthase',
#  'Protein name_23S rRNA pseudouridine(2605) synthase RluB',
#  'Protein name_23S rRNA pseudouridine(955/2504/2580) synthase',
#  'Protein name_23S rRNA pseudouridine(955/2504/2580) synthase RluC',
#  'Protein name_23S ribosomal RNA methyltransferase Erm',
#  'Protein name_2Fe-2S iron-sulfur cluster binding domain-containing protein',
#  'Protein name_2Fe-2S iron-sulfur cluster-binding protein',
#  'Protein name_2OG-Fe dioxygenase family protein',
#  'Protein name_2OG-Fe(II) oxygenase',
#  'Protein name_2OG-Fe(II) oxygenase family protein',
#  "Protein name_3'(2'),5'-bisphosphate nucleotidase",
#  "Protein name_3'(2'),5'-bisphosphate nucleotidase CysQ",
#  "Protein name_3',5'-cyclic-AMP phosphodiesterase",
#  "Protein name_3'-5' exonuclease",
#  "Protein name_3'-5' exonuclease KapD",
#  "Protein name_3'-5' exoribonuclease YhaM",
#  "Protein name_3'-5' exoribonuclease YhaM family protein",
#  "Protein name_3'-5' ssDNA/RNA exonuclease TatD",
#  'Protein name_3,4-dihydroxy-2-butanone-4-phosphate synthase',
#  'Protein name_3,4-dihydroxyphenylacetate 2,3-dioxygenase',
#  'Protein name_3,5-dihydroxyphenylacetyl-CoA synthase DpgA',
#  'Protein name_3-(3-hydroxy-phenyl)propionate transporter MhpT',
#  'Protein name_3-(3-hydroxyphenyl)propanoate hydroxylase',
#  'Protein name_3-carboxy-cis,cis-muconate cycloisomerase',
#  'Protein name_3-carboxyethylcatechol 2,3-dioxygenase',
#  'Protein name_3-dehydro-D-guloside 4-epimerase',
#  'Protein name_3-dehydro-L-gulonate 2-dehydrogenase',
#  'Protein name_3-dehydroquinase',
#  'Protein name_3-dehydroquinate dehydratase',
#  'Protein name_3-dehydroquinate synthase',
#  'Protein name_3-demethoxyubiquinol 3-hydroxylase',
#  'Protein name_3-deoxy-7-phosphoheptulonate synthase',
#  'Protein name_3-deoxy-7-phosphoheptulonate synthase AroF',
#  'Protein name_3-deoxy-7-phosphoheptulonate synthase AroG',
#  'Protein name_3-deoxy-7-phosphoheptulonate synthase AroH',
#  'Protein name_3-deoxy-7-phosphoheptulonate synthase class II',
#  'Protein name_3-deoxy-7-phosphoheptulonate synthase, Phe-sensitive',
#  'Protein name_3-deoxy-7-phosphoheptulonate synthase, Trp-sensitive',
#  'Protein name_3-deoxy-7-phosphoheptulonate synthase, Tyr-sensitive',
#  'Protein name_3-deoxy-8-phosphooctulonate synthase',
#  'Protein name_3-deoxy-D-manno-octulosonate 8-phosphate phosphatase KdsC',
#  'Protein name_3-deoxy-D-manno-octulosonic acid kinase',
#  'Protein name_3-deoxy-D-manno-octulosonic acid transferase',
#  'Protein name_3-deoxy-manno-octulosonate cytidylyltransferase',
#  'Protein name_3-deoxy-manno-octulosonate-8-phosphatase KdsC',
#  'Protein name_3-hexulose-6-phosphate synthase',
#  'Protein name_3-hydroxy acid dehydrogenase YdfG',
#  'Protein name_3-hydroxy-5-phosphonooxypentane-2,4-dione thiolase',
#  'Protein name_3-hydroxy-9,10-secoandrosta-1,3,5(10)-triene-9,17-dione monooxygenase oxygenase subunit',
#  'Protein name_3-hydroxy-9,10-secoandrosta-1,3,5(10)-triene-9,17-dione monooxygenase reductase subunit',
#  'Protein name_3-hydroxy-acyl-[acyl-carrier-protein] dehydratase',
#  'Protein name_3-hydroxyacyl-ACP dehydratase',
#  'Protein name_3-hydroxyacyl-ACP dehydratase FabZ',
#  'Protein name_3-hydroxyacyl-ACP dehydratase FabZ family protein',
#  'Protein name_3-hydroxyacyl-CoA dehydrogenase',
#  'Protein name_3-hydroxyacyl-CoA dehydrogenase NAD-binding domain-containing protein',
#  'Protein name_3-hydroxyacyl-CoA dehydrogenase family protein',
#  'Protein name_3-hydroxyacyl-CoA dehydrogenase/enoyl-CoA hydratase family protein',
#  'Protein name_3-hydroxyacyl-[acyl-carrier-protein] dehydratase FabA',
#  'Protein name_3-hydroxyanthranilate 3,4-dioxygenase',
#  'Protein name_3-hydroxybutyrate dehydrogenase',
#  'Protein name_3-hydroxybutyryl-CoA dehydrogenase',
#  'Protein name_3-hydroxyisobutyrate dehydrogenase',
#  'Protein name_3-hydroxyphenylpropionate/3-hydroxycinnamate:H(+) symporter',
#  'Protein name_3-isopropylmalate dehydratase large subunit',
#  'Protein name_3-isopropylmalate dehydratase small subunit',
#  'Protein name_3-isopropylmalate dehydratase subunit LeuC',
#  'Protein name_3-isopropylmalate dehydrogenase',
#  'Protein name_3-keto-5-aminohexanoate cleavage protein',
#  'Protein name_3-keto-L-gulonate-6-phosphate decarboxylase SgbH',
#  'Protein name_3-keto-L-gulonate-6-phosphate decarboxylase UlaD',
#  'Protein name_3-ketoacyl-ACP reductase FabG2',
#  'Protein name_3-ketoacyl-CoA thiolase',
#  'Protein name_3-ketoacyl-CoA thiolase FadI',
#  'Protein name_3-mercaptopyruvate sulfurtransferase',
#  'Protein name_3-methyl-2-oxobutanoate hydroxymethyltransferase',
#  'Protein name_3-methyl-adenine DNA glycosylase I, constitutive',
#  'Protein name_3-methyladenine DNA glycosylase',
#  'Protein name_3-octaprenyl-4-hydroxybenzoate decarboxylase',
#  'Protein name_3-oxo-5-alpha-steroid 4-dehydrogenase',
#  'Protein name_3-oxo-tetronate 4-phosphate decarboxylase',
#  'Protein name_3-oxo-tetronate kinase',
#  'Protein name_3-oxoacid CoA-transferase subunit A',
#  'Protein name_3-oxoacid CoA-transferase subunit B',
#  'Protein name_3-oxoacyl-(acyl-carrier-protein) reductase',
#  'Protein name_3-oxoacyl-ACP reductase',
#  'Protein name_3-oxoacyl-ACP reductase FabG',
#  'Protein name_3-oxoacyl-ACP reductase FabG1',
#  'Protein name_3-oxoacyl-ACP reductase family protein',
#  'Protein name_3-oxoacyl-ACP synthase III',
#  'Protein name_3-oxoacyl-ACP synthase III family protein',
#  'Protein name_3-oxoacyl-[acyl carrier protein] synthase 1',
#  'Protein name_3-oxoacyl-[acyl carrier protein] synthase 3',
#  'Protein name_3-oxoacyl-[acyl-carrier-protein] reductase',
#  'Protein name_3-oxoacyl-[acyl-carrier-protein] reductase FabG',
#  'Protein name_3-oxoacyl-[acyl-carrier-protein] synthase III C-terminal domain-containing protein',
#  'Protein name_3-oxoadipate enol-lactonase',
#  'Protein name_3-oxoadipyl-CoA thiolase',
#  'Protein name_3-oxosteroid 1-dehydrogenase',
#  'Protein name_3-phenylpropionate MFS transporter',
#  'Protein name_3-phosphoserine/phosphohydroxythreonine transaminase',
#  'Protein name_3-phosphoshikimate 1-carboxyvinyltransferase',
#  'Protein name_3-sulfolactaldehyde reductase',
#  'Protein name_30S ribosomal protein S1',
#  'Protein name_30S ribosomal protein S10',
#  'Protein name_30S ribosomal protein S11',
#  'Protein name_30S ribosomal protein S12',
#  'Protein name_30S ribosomal protein S12 methylthiotransferase RimO',
#  'Protein name_30S ribosomal protein S12 methylthiotransferase accessory factor YcaO',
#  'Protein name_30S ribosomal protein S12 methylthiotransferase accessory protein YcaO',
#  'Protein name_30S ribosomal protein S13',
#  'Protein name_30S ribosomal protein S14',
#  'Protein name_30S ribosomal protein S15',
#  'Protein name_30S ribosomal protein S16',
#  'Protein name_30S ribosomal protein S17',
#  'Protein name_30S ribosomal protein S18',
#  'Protein name_30S ribosomal protein S19',
#  'Protein name_30S ribosomal protein S2',
#  'Protein name_30S ribosomal protein S20',
#  'Protein name_30S ribosomal protein S21',
#  'Protein name_30S ribosomal protein S3',
#  'Protein name_30S ribosomal protein S4',
#  'Protein name_30S ribosomal protein S5',
#  'Protein name_30S ribosomal protein S6',
#  'Protein name_30S ribosomal protein S6--L-glutamate ligase',
#  'Protein name_30S ribosomal protein S7',
#  'Protein name_30S ribosomal protein S8',
#  'Protein name_30S ribosomal protein S9',
#  'Protein name_30S ribosomal protein THX',
#  'Protein name_30S ribosomal subunit biogenesis factor LepA',
#  'Protein name_30S ribosomal subunit maturation GTPase Era',
#  'Protein name_30S ribosomal subunit protein S10',
#  'Protein name_30S ribosomal subunit protein S11',
#  'Protein name_30S ribosomal subunit protein S12',
#  'Protein name_30S ribosomal subunit protein S13',
#  'Protein name_30S ribosomal subunit protein S14',
#  'Protein name_30S ribosomal subunit protein S15',
#  'Protein name_30S ribosomal subunit protein S16',
#  'Protein name_30S ribosomal subunit protein S17',
#  'Protein name_30S ribosomal subunit protein S18',
#  'Protein name_30S ribosomal subunit protein S19',
#  'Protein name_30S ribosomal subunit protein S2',
#  'Protein name_30S ribosomal subunit protein S21',
#  'Protein name_30S ribosomal subunit protein S3',
#  'Protein name_30S ribosomal subunit protein S4',
#  'Protein name_30S ribosomal subunit protein S6',
#  'Protein name_30S ribosomal subunit protein S7',
#  'Protein name_30S ribosomal subunit protein S8',
#  'Protein name_30S ribosomal subunit protein S9',
#  'Protein name_30S ribosome binding factor',
#  'Protein name_30S ribosome-binding factor RbfA',
#  'Protein name_3D domain-containing protein',
#  'Protein name_3D-(3,5/4)-trihydroxycyclohexane-1,2-dione acylhydrolase (decyclizing)',
#  "Protein name_4'-phosphopantetheinyl transferase",
#  "Protein name_4'-phosphopantetheinyl transferase Npt",
#  "Protein name_4'-phosphopantetheinyl transferase superfamily protein",
#  'Protein name_4,5-DOPA dioxygenase extradiol',
#  'Protein name_4,5:9,10-diseco-3-hydroxy-5,9,17-trioxoandrosta-1(10),2-diene-4-oate hydrolase',
#  "Protein name_4-(cytidine 5'-diphospho)-2-C-methyl-D-erythritol kinase",
#  'Protein name_4-alpha-glucanotransferase',
#  'Protein name_4-amino-4-deoxy-L-arabinose-phosphoundecaprenol flippase subunit ArnE',
#  'Protein name_4-amino-4-deoxy-L-arabinose-phosphoundecaprenol flippase subunit ArnF',
#  'Protein name_4-aminobutanoate:H(+) symporter',
#  'Protein name_4-aminobutyrate aminotransferase',
#  'Protein name_4-aminobutyrate aminotransferase GabT',
#  'Protein name_4-aminobutyrate aminotransferase PuuE',
#  'Protein name_4-aminobutyrate--2-oxoglutarate transaminase',
#  'Protein name_4-carboxy-4-hydroxy-2-oxoadipate aldolase/oxaloacetate decarboxylase',
#  'Protein name_4-carboxymuconolactone decarboxylase',
#  'Protein name_4-coumarate--CoA ligase family protein',
#  'Protein name_4-deoxy-4-formamido-L-arabinose-phosphoundecaprenol deformylase',
#  'Protein name_4-diphosphocytidyl-2C-methyl-D-erythritol kinase',
#  'Protein name_4-hydroxy-2-oxoheptanedioate aldolase',
#  'Protein name_4-hydroxy-2-oxovalerate aldolase',
#  'Protein name_4-hydroxy-3-methylbut-2-enyl diphosphate reductase',
#  'Protein name_4-hydroxy-3-polyprenylbenzoate decarboxylase',
#  'Protein name_4-hydroxy-tetrahydrodipicolinate reductase',
#  'Protein name_4-hydroxy-tetrahydrodipicolinate synthase',
#  'Protein name_4-hydroxybenzoate 3-monooxygenase',
#  'Protein name_4-hydroxybenzoate octaprenyltransferase',
#  'Protein name_4-hydroxyphenyl-beta-ketoacyl-CoA hydrolase',
#  'Protein name_4-hydroxyphenylacetate 3-monooxygenase reductase subunit',
#  'Protein name_4-hydroxyphenylacetate 3-monooxygenase, oxygenase component',
#  'Protein name_4-hydroxyphenylacetate 3-monooxygenase, reductase component',
#  'Protein name_4-hydroxyphenylacetate catabolism regulatory protein HpaA',
#  'Protein name_4-hydroxyphenylacetate permease',
#  'Protein name_4-hydroxyphenylpyruvate dioxygenase',
#  'Protein name_4-hydroxyproline epimerase',
#  'Protein name_4-hydroxythreonine-4-phosphate dehydrogenase PdxA',
#  'Protein name_4-oxalmesaconate hydratase',
#  'Protein name_4-oxalocrotonate tautomerase',
#  'Protein name_4-oxalocrotonate tautomerase family protein',
#  'Protein name_4-oxalomesaconate tautomerase',
#  'Protein name_4-phosphoerythronate dehydrogenase',
#  'Protein name_4-phosphoerythronate dehydrogenase PdxB',
#  'Protein name_4Fe-4S binding protein',
#  'Protein name_4Fe-4S dicluster domain-containing protein',
#  'Protein name_4Fe-4S ferredoxin-type domain-containing protein YdjY',
#  'Protein name_4Fe-4S mono-cluster protein YjdI',
#  'Protein name_4a-hydroxytetrahydrobiopterin dehydratase',
#  "Protein name_5'-3' exonuclease",
#  "Protein name_5'-3' exonuclease H3TH domain-containing protein",
#  "Protein name_5'-deoxynucleotidase",
#  "Protein name_5'-methylthioadenosine/S-adenosylhomocysteine nucleosidase",
#  "Protein name_5'-methylthioadenosine/adenosylhomocysteine nucleosidase",
#  "Protein name_5'-nucleotidase",
#  "Protein name_5'-nucleotidase C-terminal domain-containing protein",
#  "Protein name_5'-nucleotidase, lipoprotein e(P4) family",
#  "Protein name_5'-nucleotidase/UDP-sugar hydrolase",
#  "Protein name_5'/3'-nucleotidase SurE",
#  'Protein name_5,6-dimethylbenzimidazole synthase',
#  'Protein name_5-(carboxyamino)imidazole ribonucleotide mutase',
#  'Protein name_5-(carboxyamino)imidazole ribonucleotide synthase',
#  'Protein name_5-amino-6-(5-phospho-D-ribitylamino)uracil phosphatase',
#  'Protein name_5-amino-6-(5-phospho-D-ribitylamino)uracil phosphatase YigB',
#  'Protein name_5-amino-6-(D-ribitylamino)uracil--L-tyrosine 4-hydroxyphenyl transferase CofH',
#  'Protein name_5-bromo-4-chloroindolyl phosphate hydrolysis family protein',
#  'Protein name_5-carboxymethyl-2-hydroxymuconate Delta-isomerase',
#  'Protein name_5-carboxymethyl-2-hydroxymuconate semialdehyde dehydrogenase',
#  'Protein name_5-carboxymethylaminomethyluridine-tRNA synthase GTPase subunit',
#  'Protein name_5-carboxymethylaminomethyluridine-tRNA synthase subunit MnmG',
#  'Protein name_5-dehydro-2-deoxygluconokinase',
#  'Protein name_5-dehydro-4-deoxy-D-glucuronate isomerase',
#  'Protein name_5-dehydro-4-deoxyglucarate dehydratase',
#  'Protein name_5-demethoxyubiquinol-8 5-hydroxylase UbiM',
#  'Protein name_5-deoxy-glucuronate isomerase',
#  'Protein name_5-formyltetrahydrofolate cyclo-ligase',
#  'Protein name_5-histidylcysteine sulfoxide synthase',
#  'Protein name_5-hydroxy-CTP diphosphatase',
#  'Protein name_5-keto-D-gluconate 5-reductase',
#  'Protein name_5-methyltetrahydropteroyltriglutamate--homocysteine S-methyltransferase',
#  'Protein name_5-nucleotidase family protein',
#  'Protein name_5-oxoprolinase component A',
#  'Protein name_5-oxoprolinase component B',
#  'Protein name_5-oxoprolinase component C',
#  'Protein name_5-oxoprolinase subunit PxpA',
#  'Protein name_5-oxoprolinase subunit PxpB',
#  'Protein name_5-oxoprolinase subunit PxpC',
#  'Protein name_50S ribosomal protein L1',
#  'Protein name_50S ribosomal protein L10',
#  'Protein name_50S ribosomal protein L11',
#  'Protein name_50S ribosomal protein L11 methyltransferase',
#  'Protein name_50S ribosomal protein L13',
#  'Protein name_50S ribosomal protein L14',
#  'Protein name_50S ribosomal protein L15',
#  'Protein name_50S ribosomal protein L16',
#  'Protein name_50S ribosomal protein L17',
#  'Protein name_50S ribosomal protein L18',
#  'Protein name_50S ribosomal protein L19',
#  'Protein name_50S ribosomal protein L2',
#  'Protein name_50S ribosomal protein L20',
#  'Protein name_50S ribosomal protein L21',
#  'Protein name_50S ribosomal protein L22',
#  'Protein name_50S ribosomal protein L23',
#  'Protein name_50S ribosomal protein L24',
#  'Protein name_50S ribosomal protein L25',
#  'Protein name_50S ribosomal protein L25/general stress protein Ctc',
#  'Protein name_50S ribosomal protein L27',
#  'Protein name_50S ribosomal protein L28',
#  'Protein name_50S ribosomal protein L29',
#  'Protein name_50S ribosomal protein L3',
#  'Protein name_50S ribosomal protein L3 N(5)-glutamine methyltransferase',
#  'Protein name_50S ribosomal protein L30',
#  'Protein name_50S ribosomal protein L31',
#  'Protein name_50S ribosomal protein L31 type B',
#  'Protein name_50S ribosomal protein L32',
#  'Protein name_50S ribosomal protein L33',
#  'Protein name_50S ribosomal protein L34',
#  'Protein name_50S ribosomal protein L35',
#  'Protein name_50S ribosomal protein L36',
#  'Protein name_50S ribosomal protein L4',
#  'Protein name_50S ribosomal protein L5',
#  'Protein name_50S ribosomal protein L6',
#  'Protein name_50S ribosomal protein L7 serine acetyltransferase',
#  'Protein name_50S ribosomal protein L7/L12',
#  'Protein name_50S ribosomal protein L7/L12-serine acetyltransferase',
#  'Protein name_50S ribosomal protein L7Ae-like protein',
#  'Protein name_50S ribosomal protein L9',
#  'Protein name_50S ribosomal subunit assembly factor BipA',
#  'Protein name_50S ribosomal subunit protein L11',
#  'Protein name_50S ribosomal subunit protein L12',
#  'Protein name_50S ribosomal subunit protein L13',
#  'Protein name_50S ribosomal subunit protein L14',
#  'Protein name_50S ribosomal subunit protein L15',
#  'Protein name_50S ribosomal subunit protein L16',
#  'Protein name_50S ribosomal subunit protein L17',
#  'Protein name_50S ribosomal subunit protein L18',
#  'Protein name_50S ribosomal subunit protein L2',
#  'Protein name_50S ribosomal subunit protein L20',
#  'Protein name_50S ribosomal subunit protein L21',
#  'Protein name_50S ribosomal subunit protein L22',
#  'Protein name_50S ribosomal subunit protein L25',
#  'Protein name_50S ribosomal subunit protein L27',
#  'Protein name_50S ribosomal subunit protein L28',
#  'Protein name_50S ribosomal subunit protein L29',
#  'Protein name_50S ribosomal subunit protein L3',
#  'Protein name_50S ribosomal subunit protein L31',
#  'Protein name_50S ribosomal subunit protein L31B',
#  'Protein name_50S ribosomal subunit protein L32',
#  'Protein name_50S ribosomal subunit protein L33',
#  'Protein name_50S ribosomal subunit protein L34',
#  'Protein name_50S ribosomal subunit protein L35',
#  'Protein name_50S ribosomal subunit protein L36',
#  'Protein name_50S ribosomal subunit protein L36B',
#  'Protein name_50S ribosomal subunit protein L6',
#  'Protein name_50S ribosomal subunit protein L9',
#  'Protein name_50S ribosomal subunit stability factor',
#  'Protein name_50S ribosome-binding GTPase',
#  'Protein name_6,7-dimethyl-8-ribityllumazine synthase',
#  'Protein name_6-carboxy-5,6,7,8-tetrahydropterin synthase',
#  'Protein name_6-carboxyhexanoate--CoA ligase',
#  'Protein name_6-carboxytetrahydropterin synthase',
#  'Protein name_6-carboxytetrahydropterin synthase QueD',
#  'Protein name_6-deoxy-6-sulfofructose kinase',
#  'Protein name_6-deoxy-6-sulfofructose-1-phosphate aldolase',
#  'Protein name_6-hydroxyaminopurine reductase',
#  'Protein name_6-hydroxymethylpterin diphosphokinase MptE-like protein',
#  'Protein name_6-phospho-3-hexuloisomerase',
#  'Protein name_6-phospho-alpha-glucosidase',
#  'Protein name_6-phospho-beta-galactosidase',
#  'Protein name_6-phospho-beta-glucosidase',
#  'Protein name_6-phospho-beta-glucosidase A',
#  'Protein name_6-phospho-beta-glucosidase AscB',
#  'Protein name_6-phospho-beta-glucosidase B',
#  'Protein name_6-phospho-beta-glucosidase BglA',
#  'Protein name_6-phosphofructokinase',
#  'Protein name_6-phosphofructokinase 1',
#  'Protein name_6-phosphofructokinase 2',
#  'Protein name_6-phosphofructokinase II',
#  'Protein name_6-phosphogluconate dehydrogenase',
#  'Protein name_6-phosphogluconate dehydrogenase, decarboxylating',
#  'Protein name_6-phosphogluconate phosphatase',
#  'Protein name_6-phosphogluconolactonase',
#  'Protein name_7,8-didemethyl-8-hydroxy-5-deazariboflavin synthase CofG',
#  'Protein name_7-alpha-hydroxysteroid dehydrogenase',
#  'Protein name_7-carboxy-7-deazaguanine synthase QueE',
#  'Protein name_7-cyano-7-deazaguanine reductase',
#  'Protein name_7-cyano-7-deazaguanine synthase',
#  'Protein name_7-cyano-7-deazaguanine synthase QueC',
#  'Protein name_7-cyano-7-deazaguanine/7-aminomethyl-7-deazaguanine transporter',
#  'Protein name_7-cyano-7-deazaguanosine (preQ0) biosynthesis protein QueE',
#  'Protein name_8-amino-7-oxononanoate synthase',
#  'Protein name_8-oxo-dGTP diphosphatase',
#  'Protein name_8-oxo-dGTP diphosphatase MutT',
#  'Protein name_8-oxoguanine deaminase',
#  'Protein name_A/G-specific adenine glycosylase',
#  'Protein name_A24 family peptidase',
#  'Protein name_AAA domain-containing protein',
#  'Protein name_AAA family ATPase',
#  'Protein name_AAC(3) family N-acetyltransferase',
#  'Protein name_ABA4-like family protein',
#  'Protein name_ABATE domain-containing protein',
#  'Protein name_ABC exporter membrane subunit YbhR',
#  'Protein name_ABC family protein ModF',
#  'Protein name_ABC transporter',
#  'Protein name_ABC transporter ATP-binding protein',
#  'Protein name_ABC transporter ATP-binding protein AfuC',
#  'Protein name_ABC transporter ATP-binding protein/permease',
#  'Protein name_ABC transporter ATP-binding subunit Vex2',
#  'Protein name_ABC transporter ATP-binding/permease',
#  'Protein name_ABC transporter family protein MdlA',
#  'Protein name_ABC transporter family protein MdlB',
#  'Protein name_ABC transporter family protein YddA',
#  'Protein name_ABC transporter family protein YhhJ',
#  'Protein name_ABC transporter family protein/microcin J25 efflux protein',
#  'Protein name_ABC transporter family substrate-binding protein',
#  'Protein name_ABC transporter permease',
#  'Protein name_ABC transporter permease subunit',
#  'Protein name_ABC transporter permease subunit Vex3',
#  'Protein name_ABC transporter six-transmembrane domain-containing protein',
#  'Protein name_ABC transporter substrate binding protein',
#  'Protein name_ABC transporter substrate-binding protein',
#  'Protein name_ABC transporter substrate-binding protein SapA',
#  'Protein name_ABC transporter substrate-binding protein/permease',
#  'Protein name_ABC transporter transmembrane domain-containing protein',
#  'Protein name_ABC-2 family transporter protein',
#  'Protein name_ABC-2 transporter permease',
#  'Protein name_ABC-F family ATP-binding cassette domain-containing protein',
#  'Protein name_ABC-F family ATPase',
#  'Protein name_ABC-three component system protein',
#  'Protein name_ABC-type transport auxiliary lipoprotein family protein',
#  'Protein name_ABC-type tripartite efflux pump ATP binding/membrane subunit',
#  'Protein name_ABC-type tripartite efflux pump membrane fusion protein',
#  'Protein name_ACP S-malonyltransferase',
#  'Protein name_ACP phosphodiesterase',
#  'Protein name_ACR3 family arsenite efflux transporter',
#  'Protein name_ACT domain-containing protein',
#  'Protein name_ADP compounds hydrolase NudE',
#  'Protein name_ADP-L-glycero-D-mannoheptose 6-epimerase',
#  'Protein name_ADP-forming succinate--CoA ligase subunit beta',
#  'Protein name_ADP-glyceromanno-heptose 6-epimerase',
#  'Protein name_ADP-heptose--LPS heptosyltransferase 2',
#  'Protein name_ADP-heptose--LPS heptosyltransferase RfaF',
#  'Protein name_ADP-ribose diphosphatase',
#  'Protein name_ADP-ribosylglycohydrolase',
#  'Protein name_ADP-ribosylglycohydrolase family protein',
#  'Protein name_ADP-ribosyltransferase',
#  'Protein name_ADP-sugar diphosphatase NudE',
#  'Protein name_ADP-sugar pyrophosphatase',
#  'Protein name_AEC family transporter',
#  'Protein name_AGE family epimerase/isomerase',
#  'Protein name_AI-2E family transporter',
#  'Protein name_AI-2E family transporter YdiK',
#  'Protein name_AIM24 family protein',
#  'Protein name_AIPR family protein',
#  'Protein name_AIR carboxylase family protein',
#  'Protein name_AIR synthase related protein',
#  'Protein name_AIR synthase-related protein',
#  'Protein name_ALF repeat-containing protein',
#  'Protein name_AMP nucleosidase',
#  'Protein name_AMP-binding protein',
#  'Protein name_AMP-dependent synthetase/ligase',
#  'Protein name_ANTAR domain-containing protein',
#  'Protein name_ANTAR domain-containing response regulator',
#  'Protein name_APC family permease',
#  "Protein name_APH(3')-II family aminoglycoside O-phosphotransferase",
#  'Protein name_APH(6) family putative aminoglycoside O-phosphotransferase',
#  'Protein name_ASCH domain-containing protein',
#  'Protein name_ATP cone domain-containing protein',
#  'Protein name_ATP phosphoribosyltransferase',
#  'Protein name_ATP phosphoribosyltransferase catalytic subunit',
#  'Protein name_ATP phosphoribosyltransferase regulatory subunit',
#  'Protein name_ATP synthase F0 subunit B',
#  'Protein name_ATP synthase F0 subunit C',
#  'Protein name_ATP synthase F1 complex subunit beta',
#  'Protein name_ATP synthase F1 complex subunit delta',
#  'Protein name_ATP synthase F1 complex subunit epsilon',
#  'Protein name_ATP synthase F1 complex subunit gamma',
#  'Protein name_ATP synthase F1 subunit delta',
#  'Protein name_ATP synthase F1 subunit epsilon',
#  'Protein name_ATP synthase F1 subunit gamma',
#  'Protein name_ATP synthase Fo complex subunit a',
#  'Protein name_ATP synthase Fo complex subunit b',
#  'Protein name_ATP synthase accessory factor AtpI',
#  'Protein name_ATP synthase subunit C',
#  'Protein name_ATP synthase subunit I',
#  'Protein name_ATP--cob(I)alamin adenosyltransferase',
#  'Protein name_ATP-NAD kinase',
#  'Protein name_ATP-NAD kinase family protein',
#  'Protein name_ATP-binding cassette domain-containing protein',
#  'Protein name_ATP-binding domain-containing protein',
#  'Protein name_ATP-binding lipopolysaccharide transport protein',
#  'Protein name_ATP-binding protein',
#  'Protein name_ATP-binding protein PhoH',
#  'Protein name_ATP-binding protein/SpoIIE family protein phosphatase',
#  'Protein name_ATP-binding sensor histidine kinase',
#  "Protein name_ATP-dependent 3'->5' RNA helicase HrpA",
#  'Protein name_ATP-dependent 6-phosphofructokinase',
#  'Protein name_ATP-dependent Clp endopeptidase proteolytic subunit ClpP',
#  'Protein name_ATP-dependent Clp protease ATP-binding subunit',
#  'Protein name_ATP-dependent Clp protease ATP-binding subunit ClpA',
#  'Protein name_ATP-dependent Clp protease ATP-binding subunit ClpB',
#  'Protein name_ATP-dependent Clp protease ATP-binding subunit ClpC',
#  'Protein name_ATP-dependent Clp protease ATP-binding subunit ClpX',
#  'Protein name_ATP-dependent Clp protease adapter ClpS',
#  'Protein name_ATP-dependent Clp protease proteolytic subunit',
#  'Protein name_ATP-dependent DNA helicase',
#  'Protein name_ATP-dependent DNA helicase DinG',
#  'Protein name_ATP-dependent DNA helicase PcrA',
#  'Protein name_ATP-dependent DNA helicase RecG',
#  'Protein name_ATP-dependent DNA helicase RecQ',
#  'Protein name_ATP-dependent DNA helicase Rep',
#  'Protein name_ATP-dependent DNA helicase UvrD2',
#  'Protein name_ATP-dependent DNA ligase',
#  'Protein name_ATP-dependent RNA helicase DbpA',
#  'Protein name_ATP-dependent RNA helicase DeaD',
#  'Protein name_ATP-dependent RNA helicase HrpA',
#  'Protein name_ATP-dependent RNA helicase RhlB',
#  'Protein name_ATP-dependent RNA helicase RhlE',
#  'Protein name_ATP-dependent RNA helicase SrmB',
#  'Protein name_ATP-dependent RecD-like DNA helicase',
#  'Protein name_ATP-dependent chaperone ClpB',
#  'Protein name_ATP-dependent endonuclease',
#  'Protein name_ATP-dependent helicase',
#  'Protein name_ATP-dependent helicase C-terminal domain-containing protein',
#  'Protein name_ATP-dependent helicase HrpB',
#  'Protein name_ATP-dependent helicase Lhr',
#  'Protein name_ATP-dependent metallopeptidase FtsH/Yme1/Tma family protein',
#  'Protein name_ATP-dependent nuclease subunit A',
#  'Protein name_ATP-dependent protease ATP-binding subunit ClpC',
#  'Protein name_ATP-dependent protease ATP-binding subunit ClpX',
#  'Protein name_ATP-dependent protease LonB',
#  'Protein name_ATP-dependent protease peptidase subunit',
#  'Protein name_ATP-dependent protease subunit HslV',
#  'Protein name_ATP-dependent sacrificial sulfur transferase LarE',
#  'Protein name_ATP-dependent structure-specific DNA nuclease - SbcC subunit',
#  'Protein name_ATP-dependent structure-specific DNA nuclease - SbcD subunit',
#  'Protein name_ATP-dependent zinc metalloprotease FtsH',
#  'Protein name_ATP-dependent zinc protease',
#  'Protein name_ATP-grasp domain-containing protein',
#  'Protein name_ATP-grasp fold amidoligase family protein',
#  'Protein name_ATP-grasp peptide maturase system methyltransferase',
#  'Protein name_ATP-grasp ribosomal peptide maturase',
#  'Protein name_ATP-independent periplasmic chaperone',
#  'Protein name_ATP-independent periplasmic protein-refolding chaperone Spy',
#  'Protein name_ATP/GTP-binding protein',
#  'Protein name_ATP:cob(I)alamin adenosyltransferase',
#  'Protein name_ATP:guanido phosphotransferase',
#  'Protein name_ATPase AAA',
#  'Protein name_ATPase RavA',
#  'Protein name_ATPase RavA stimulator ViaA',
#  'Protein name_ATPase component of the HslVU protease',
#  'Protein name_ATPase domain-containing protein',
#  'Protein name_ATPase, T2SS/T4P/T4SS family',
#  'Protein name_AURKAIP1/COX24 domain-containing protein',
#  'Protein name_AarF/ABC1/UbiB kinase family protein',
#  'Protein name_AarF/UbiB family protein',
#  'Protein name_AbfB domain-containing protein',
#  'Protein name_AbgT family transporter',
#  'Protein name_Abi family protein',
#  'Protein name_Abi-alpha family protein',
#  'Protein name_AbiEi antitoxin N-terminal domain-containing protein',
#  'Protein name_AbrB family transcriptional regulator',
#  'Protein name_AbrB/MazE/SpoVT family DNA-binding domain-containing protein',
#  'Protein name_AcnB',
#  'Protein name_AcrZ family multidrug efflux pump-associated protein',
#  'Protein name_AcvB/VirJ family lysyl-phosphatidylglycerol hydrolase',
#  'Protein name_Ada metal-binding domain-containing protein',
#  'Protein name_AfaD family invasin',
#  'Protein name_AfsA-related hotdog domain-containing protein',
#  'Protein name_AfsR/SARP family transcriptional regulator',
#  'Protein name_Ag(+)-translocating P-type ATPase SilP',
#  'Protein name_AhpA/YtjB family protein',
#  'Protein name_Ail/Lom family outer membrane beta-barrel protein',
#  'Protein name_AlkA N-terminal domain-containing protein',
#  'Protein name_AlpA family phage regulatory protein',
#  'Protein name_AlpA family transcriptional regulator',
#  'Protein name_AlwI family type II restriction endonuclease',
#  'Protein name_AmmeMemoRadiSam system protein B',
#  'Protein name_AmmeMemoRadiSam system radical SAM enzyme',
#  'Protein name_AmpG family muropeptide MFS transporter',
#  'Protein name_AprI/Inh family metalloprotease inhibitor',
#  'Protein name_AraC family transcriptional regulator',
#  'Protein name_Arc family DNA binding domain-containing protein',
#  'Protein name_Arc family DNA-binding protein',
#  'Protein name_ArgE/DapE family deacylase',
#  'Protein name_ArgR family transcriptional regulator',
#  'Protein name_AroM family protein',
#  'Protein name_ArsA family ATPase',
#  'Protein name_ArsA-related P-loop ATPase',
#  'Protein name_ArsB/NhaD family transporter',
#  'Protein name_ArsC family reductase',
#  'Protein name_ArsI/CadI family heavy metal resistance metalloenzyme',
#  'Protein name_ArsR family transcriptional regulator',
#  'Protein name_AsmA family protein',
#  'Protein name_AsmA family protein YhjG',
#  'Protein name_AsmA family protein YicH',
#  'Protein name_AsmA2 domain-containing protein YhdP',
#  'Protein name_AsnC family transcriptional regulator',
#  'Protein name_Asp-tRNA(Asn)/Glu-tRNA(Gln) amidotransferase subunit GatA',
#  'Protein name_Asp-tRNA(Asn)/Glu-tRNA(Gln) amidotransferase subunit GatB',
#  'Protein name_Asp-tRNA(Asn)/Glu-tRNA(Gln) amidotransferase subunit GatC',
#  'Protein name_Asp/Glu racemase',
#  'Protein name_Asp23/Gls24 family envelope stress response protein',
#  'Protein name_AtpZ/AtpI family protein',
#  'Protein name_AtsA/ElaC family protein',
#  'Protein name_Atu2307/SP_0267 family LLM class monooxygenase',
#  'Protein name_AtzE family amidohydrolase',
#  'Protein name_Autoinducer-2 ABC transporter ATP binding subunit',
#  'Protein name_Autoinducer-2 ABC transporter membrane subunit LsrC',
#  'Protein name_Autoinducer-2 ABC transporter membrane subunit LsrD',
#  'Protein name_Autoinducer-2 ABC transporter periplasmic binding protein',
#  'Protein name_Ax21 family protein',
#  'Protein name_AzlC family ABC transporter permease',
#  'Protein name_AzlD domain-containing protein',
#  'Protein name_AzlD family protein',
#  'Protein name_B-4DMT family transporter',
#  'Protein name_B12-binding domain-containing protein',
#  'Protein name_B3/4 domain-containing protein',
#  'Protein name_BBE domain-containing protein',
#  'Protein name_BCCT family osmoprotectant transporter',
#  'Protein name_BCCT family transporter',
#  'Protein name_BLUF domain-containing protein',
#  'Protein name_BMC domain-containing protein',
#  'Protein name_BMP family ABC transporter substrate-binding protein',
#  'Protein name_BMP family protein',
#  'Protein name_BNR repeat-containing protein',
#  'Protein name_BOF family protein YdeI',
#  'Protein name_BOF family protein YgiW',
#  'Protein name_BON domain-containing protein',
#  'Protein name_BPL-N domain-containing protein',
#  'Protein name_BPSS1780 family membrane protein',
#  'Protein name_BPU family class D beta-lactamase',
#  'Protein name_BRCT domain-containing protein',
#  'Protein name_BREX system P-loop protein BrxC',
#  'Protein name_BREX-1 system adenine-specific DNA-methyltransferase PglX',
#  'Protein name_BREX-1 system phosphatase PglZ type A',
#  'Protein name_BREX-3 system phosphatase PglZ',
#  'Protein name_BTAD domain-containing putative transcriptional regulator',
#  'Protein name_BadF/BadG/BcrA/BcrD ATPase family protein',
#  'Protein name_BamA/TamA family outer membrane protein',
#  'Protein name_BatA domain-containing protein',
#  'Protein name_BatD family protein',
#  'Protein name_Bax inhibitor-1/YccA family protein',
#  'Protein name_Bax1-I family protein YbhL',
#  'Protein name_Bax1-I family protein YbhM',
#  'Protein name_Bcr/CflA family multidrug efflux MFS transporter',
#  'Protein name_BglG family transcription antiterminator',
#  'Protein name_BlaI/MecI/CopY family transcriptional regulator',
#  'Protein name_BldC family transcriptional regulator',
#  'Protein name_BolA family iron metabolism protein IbaG',
#  'Protein name_BolA family protein',
#  'Protein name_BolA/IbaG family iron-sulfur metabolism protein',
#  'Protein name_BrnA antitoxin family protein',
#  'Protein name_BrnT family toxin',
#  'Protein name_Bro-N domain-containing protein',
#  'Protein name_BrxA/BrxB family bacilliredoxin',
#  'Protein name_BsuPI-related putative proteinase inhibitor',
#  'Protein name_BtpA/SgcQ family protein',
#  'Protein name_BtrH N-terminal domain-containing protein',
#  'Protein name_C-terminal binding protein',
#  'Protein name_C-terminal helicase domain-containing protein',
#  'Protein name_C-type lysozyme inhibitor',
#  'Protein name_C-type natriuretic protein',
#  'Protein name_C1 family peptidase',
#  'Protein name_C25 family cysteine peptidase',
#  'Protein name_C4-dicarboxylate TRAP transporter substrate-binding protein',
#  'Protein name_C4-dicarboxylate transporter DctA',
#  'Protein name_C4-dicarboxylate transporter DctP',
#  'Protein name_C4-dicarboxylate transporter DcuA',
#  'Protein name_C4-dicarboxylate transporter DcuC',
#  'Protein name_C4-dicarboxylic acid transporter DauA',
#  'Protein name_C4-type zinc ribbon domain-containing protein',
#  'Protein name_C40 family peptidase',
#  'Protein name_C45 family autoproteolytic acyltransferase/hydolase',
#  'Protein name_C45 family peptidase',
#  'Protein name_C69 family dipeptidase',
#  'Protein name_CAP domain-containing protein',
#  'Protein name_CBM35 domain-containing protein',
#  'Protein name_CBS and ACT domain-containing protein',
#  'Protein name_CBS domain-containing protein',
#  'Protein name_CBS-HotDog domain-containing transcription factor SpxR',
#  'Protein name_CCA tRNA nucleotidyltransferase',
#  'Protein name_CD20-like domain-containing protein',
#  'Protein name_CD225/dispanin family protein',
#  'Protein name_CDF family Co(II)/Ni(II) efflux transporter DmeF',
#  'Protein name_CDF family cation-efflux transporter FieF',
#  'Protein name_CDF family zinc transporter ZitB',
#  'Protein name_CDGSH iron-sulfur domain-containing protein',
#  'Protein name_CDP-6-deoxy-delta-3,4-glucoseen reductase',
#  'Protein name_CDP-alcohol phosphatidyltransferase domain-containing protein YnbA',
#  'Protein name_CDP-alcohol phosphatidyltransferase domain-containing protein YnjF',
#  'Protein name_CDP-alcohol phosphatidyltransferase family protein',
#  'Protein name_CDP-diacylglycerol O-phosphatidyltransferase',
#  'Protein name_CDP-diacylglycerol diphosphatase',
#  'Protein name_CDP-diacylglycerol--glycerol-3-phosphate 3-phosphatidyltransferase',
#  'Protein name_CDP-diacylglycerol--serine O-phosphatidyltransferase',
#  'Protein name_CDP-diglyceride synthetase',
#  'Protein name_CDP-glucose 4,6-dehydratase',
#  'Protein name_CDP-glycerol glycerophosphotransferase family protein',
#  'Protein name_CDP-glycerol--glycerophosphate glycerophosphotransferase',
#  'Protein name_CEACAM-binding trimeric autotransporter adhesin CbpF',
#  'Protein name_CGNR zinc finger domain-containing protein',
#  'Protein name_CHAD domain-containing protein',
#  'Protein name_CHAP domain-containing protein',
#  'Protein name_CHASE2 domain-containing protein',
#  'Protein name_CHAT domain-containing protein',
#  'Protein name_CHRD domain-containing protein',
#  'Protein name_CHY zinc finger protein',
#  'Protein name_CIA30 family protein',
#  'Protein name_CII family transcriptional regulator',
#  'Protein name_CMD domain-containing protein',
#  'Protein name_CNNM domain-containing protein',
#  'Protein name_CNNM family cation transport protein YoaE',
#  'Protein name_CNNM family magnesium/cobalt transport protein CorC',
#  'Protein name_COX15/CtaA family protein',
#  'Protein name_CPBP family glutamic-type intramembrane protease',
#  'Protein name_CPBP family intramembrane glutamic endopeptidase',
#  'Protein name_CPBP family intramembrane metalloprotease',
#  'Protein name_CPCC family cysteine-rich protein',
#  'Protein name_CPXCG motif-containing cysteine-rich protein',
#  'Protein name_CRISPR-associated endonuclease Cas2',
#  "Protein name_CRISPR-associated endonuclease Cas3''",
#  'Protein name_CRISPR-associated endonuclease/helicase Cas3',
#  'Protein name_CRISPR-associated endoribonuclease Cas6',
#  "Protein name_CRISPR-associated helicase Cas3'",
#  'Protein name_CRISPR-associated helicase/endonuclease Cas3',
#  'Protein name_CS1 type fimbrial major subunit',
#  'Protein name_CTP synthase',
#  'Protein name_CTP synthase (glutamine hydrolyzing)',
#  'Protein name_CTP synthetase',
#  'Protein name_CU044_2847 family protein',
#  'Protein name_CU044_5270 family protein',
#  'Protein name_CYTH and CHAD domain-containing protein',
#  'Protein name_CYTH domain-containing protein',
#  'Protein name_Cache 3/Cache 2 fusion domain-containing protein',
#  'Protein name_CaiB/BaiF CoA-transferase family protein',
#  'Protein name_CamS family sex pheromone protein',
#  'Protein name_CapA family protein',
#  'Protein name_CarD family transcriptional regulator',
#  'Protein name_CatA-like O-acetyltransferase, family 1',
#  'Protein name_CatB-related O-acetyltransferase',
#  'Protein name_CbiQ family ECF transporter T component',
#  'Protein name_CbiX/SirB N-terminal domain-containing protein',
#  'Protein name_CbrC family protein',
#  'Protein name_CbtA family protein',
#  'Protein name_CbtB-domain containing protein',
#  'Protein name_CcdB family protein',
#  'Protein name_CcoQ/FixQ family Cbb3-type cytochrome c oxidase assembly chaperone',
#  'Protein name_CdaR family transcriptional regulator',
#  'Protein name_CdiA family toxin C-terminal domain-containing protein',
#  'Protein name_CehA/McbA family metallohydrolase',
#  'Protein name_CerR family C-terminal domain-containing protein',
#  'Protein name_CfaE/CblD family pilus tip adhesin',
#  'Protein name_ChaB family protein',
#  'Protein name_ChaN family lipoprotein',
#  'Protein name_ChbR',
#  'Protein name_CheR family methyltransferase',
#  'Protein name_ChiQ/YbfN family lipoprotein',
#  'Protein name_ChrR family anti-sigma-E factor',
#  'Protein name_ChuX/HutX family heme-like substrate-binding protein',
#  'Protein name_CidA/LrgA family holin-like protein',
#  'Protein name_CidA/LrgA family protein',
#  'Protein name_CidB/LrgB family autolysis modulator',
#  'Protein name_CinA family nicotinamide mononucleotide deamidase-related protein',
#  'Protein name_CinA family protein',
#  'Protein name_CitMHS family transporter',
#  'Protein name_ClC family H(+)/Cl(-) exchange transporter',
#  'Protein name_ClbS/DfsB family four-helix bundle protein',
#  'Protein name_Clp protease ClpP',
#  'Protein name_Clp protease N-terminal domain-containing protein',
#  'Protein name_ClpB80',
#  'Protein name_ClpP family protease',
#  'Protein name_ClpXP adapter SpxH family protein',
#  'Protein name_ClpXP protease specificity-enhancing factor',
#  'Protein name_CmpA/NrtA family ABC transporter substrate-binding protein',
#  'Protein name_Cna B-type domain-containing protein',
#  'Protein name_Co2+/Mg2+ efflux protein ApaG',
#  'Protein name_CoA ester lyase',
#  'Protein name_CoA pyrophosphatase',
#  'Protein name_CoA transferase',
#  'Protein name_CoA transferase subunit A',
#  'Protein name_CoA transferase subunit B',
#  'Protein name_CoA-acylating methylmalonate-semialdehyde dehydrogenase',
#  'Protein name_CoA-acylating propionaldehyde dehydrogenase PduP',
#  'Protein name_CoA-binding protein',
#  'Protein name_CoA-disulfide reductase',
#  'Protein name_CoA-transferase',
#  'Protein name_CobB-S',
#  'Protein name_CobW family GTP-binding protein',
#  'Protein name_CocE/NonD family hydrolase',
#  'Protein name_CocE/NonD family hydrolase C-terminal non-catalytic domain-containing protein',
#  'Protein name_Cof-type HAD-IIB family hydrolase',
#  'Protein name_ComE operon protein 2',
#  'Protein name_ComEA family DNA-binding protein',
#  'Protein name_ComEC family protein',
#  'Protein name_ComEC/Rec2 family competence protein',
#  'Protein name_ComF family protein',
#  'Protein name_CopC domain-containing protein YobA',
#  'Protein name_CopD family protein',
#  'Protein name_CopG family ribbon-helix-helix protein',
#  'Protein name_CopG family transcriptional regulator',
#  'Protein name_CopL family metal-binding regulatory protein',
#  'Protein name_CopY/TcrY family copper transport repressor',
#  'Protein name_CorA family divalent cation transporter',
#  'Protein name_CorC-HlyC family protein YbeX',
#  'Protein name_CotD family spore coat protein',
#  'Protein name_CotH kinase family protein',
#  'Protein name_CotO family spore coat protein',
#  'Protein name_CotY/CotZ family spore coat protein',
#  'Protein name_CotZ-related putative spore coat protein',
#  'Protein name_Cox family DNA-binding protein',
#  'Protein name_CpaF family protein',
#  'Protein name_CpaF/VirB11 family protein',
#  'Protein name_CphA family subclass B2 metallo-beta-lactamase',
#  'Protein name_CppA N-terminal domain-containing protein',
#  'Protein name_CrcB family protein',
#  'Protein name_CreA family protein',
#  'Protein name_Cro/CI family transcriptional regulator',
#  'Protein name_Cro/Cl family transcriptional regulator',
#  'Protein name_Crp/Fnr family transcriptional regulator',
#  'Protein name_CsbA family protein',
#  'Protein name_CsbD family protein',
#  'Protein name_CsgG/HfaB family protein',
#  'Protein name_CspA family protein CspH',
#  'Protein name_CstA-like transporter-associated (seleno)protein',
#  'Protein name_Cthe_2314 family HEPN domain-containing protein',
#  'Protein name_CtsR family transcriptional regulator',
#  'Protein name_Cu(+)/Ag(+) efflux RND transporter outer membrane channel SilC',
#  'Protein name_Cu(+)/Ag(+) efflux RND transporter periplasmic adaptor subunit SilB',
#  'Protein name_Cu(+)/Ag(+) efflux RND transporter permease subunit SilA',
#  'Protein name_Cu(+)/Ag(+) sensor histidine kinase',
#  'Protein name_Cu(I)-responsive transcriptional regulator',
#  'Protein name_CusA/CzcA family heavy metal efflux RND transporter',
#  'Protein name_CvpA family protein',
#  'Protein name_CxxH/CxxC protein',
#  'Protein name_CynX/NimT family MFS transporter',
#  'Protein name_Cys-tRNA(Pro) deacylase',
#  'Protein name_Cys-tRNA(Pro)/Cys-tRNA(Cys) deacylase YbaK',
#  'Protein name_D-2-hydroxyacid dehydrogenase',
#  'Protein name_D-2-hydroxyacid dehydrogenase family protein',
#  'Protein name_D-3-phosphoglycerate dehydrogenase',
#  'Protein name_D-alanine aminotransferase',
#  'Protein name_D-alanine transfer protein DltB',
#  'Protein name_D-alanine--D-alanine ligase',
#  'Protein name_D-alanine--D-alanine ligase A',
#  'Protein name_D-alanine--D-alanine ligase B',
#  'Protein name_D-alanine--D-alanine ligase family protein',
#  ...]

# %%
df_fi = pd.DataFrame(data = pipe_model["RF_model"].feature_importances_, index=new_features, #index=X.columns
                      columns = ["Feature Importance"])
df_fi = df_fi.sort_values("Feature Importance", ascending=False)

df_fi.head(10)
# Out:
#                                                     Feature Importance
# standardscaler__Protein length                                0.320118
# Protein name_hypothetical protein                             0.029448
# Protein name_LysR family transcriptional regulator            0.003857
# Protein name_acyl-CoA dehydrogenase family protein            0.001291
# Protein name_helix-turn-helix domain-containing...            0.001177
# Protein name_MFS transporter                                  0.001154
# Protein name_ABC transporter ATP-binding protein              0.001054
# Protein name_TetR/AcrR family transcriptional r...            0.001051
# Protein name_cytochrome P450                                  0.000988
# Protein name_ATP-binding protein                              0.000941

# %%
from xgboost import XGBClassifier

# %%
operations = [("OneHotEncoder", column_trans),
              ("XGB_model", XGBClassifier(random_state=11))]

pipe_model = Pipeline(steps=operations)

pipe_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('OneHotEncoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   Index(['Orientation', 'Protein name'], dtype='object')),
#                                                  ('standardscaler',
#                                                   StandardScaler(),
#                                                   Index(['Protein length'], dtype='object'))])),
#                 ('XGB_model',
#                  XGBClassifier(base_score=None, booster=None, callbacks=None,
#                                co...
#                                feature_types=None, gamma=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None, learning_rate=None,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=None, max_leaves=None,
#                                min_child_weight=None, missing=nan,
#                                monotone_constraints=None, multi_strategy=None,
#                                n_estimators=None, n_jobs=None,
#                                num_parallel_tree=None, random_state=11, ...))])

# %%
calculate_results(y_true=y_test,
                  y_pred=(pipe_model.predict(X_test)))
# Out:
# {'accuracy': 0.6045112781954888,
#  'precision': 0.6570734568028934,
#  'recall': 0.6045112781954888,
#  'f1': 0.5684362475539015}

# %% [markdown]
# # ANN

# %%
X_train
# Out:
#       Orientation                                  Protein name  \
# 46032        plus                           glycoside hydrolase
# 82630        plus                          hypothetical protein
# 6783         plus                          hypothetical protein
# 83620       minus                       OmpA family lipoprotein
# 86383       minus                          hypothetical protein
# ...           ...                                           ...
# 23452        plus                          hypothetical protein
# 75453        plus             DUF4158 domain-containing protein
# 40904        plus                YcgL domain-containing protein
# 47111        plus  crotonase/enoyl-CoA hydratase family protein
# 1395         plus             glycine--tRNA ligase subunit beta
#
#        Protein length
# 46032           733.0
# 82630            57.0
# 6783             31.0
# 83620           219.0
# 86383            66.0
# ...               ...
# 23452            87.0
# 75453           344.0
# 40904            86.0
# 47111           268.0
# 1395            681.0
#
# [69156 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86446 entries, 0 to 86445
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Orientation     86446 non-null  object
#  1   Protein name    86446 non-null  object
#  2   Protein length  86446 non-null  float64
#  3   Target          86446 non-null  float64
# dtypes: float64(2), object(2)
# memory usage: 2.6+ MB

# %%
cat = X_train.select_dtypes("object").columns
cat
num = X_train.select_dtypes("float64").columns
num
# Out:
# Index(['Protein length'], dtype='object')

# %%
num
# Out:
# Index(['Protein length'], dtype='object')

# %%
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder
from sklearn.preprocessing import StandardScaler

enc = OneHotEncoder()
enc.fit_transform(X_train[cat])
X_test[cat] = enc.transform(X_test[cat])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 6
#       4 enc = OneHotEncoder()
#       5 enc.fit_transform(X_train[cat])
# ----> 6 X_test[cat] = enc.transform(X_test[cat])
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/utils/_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:917, in OneHotEncoder.transform(self, X)
#     912 # validation of X happens in _check_X called by _transform
#     913 warn_on_unknown = self.drop is not None and self.handle_unknown in {
#     914     "ignore",
#     915     "infrequent_if_exist",
#     916 }
# --> 917 X_int, X_mask = self._transform(
#     918     X,
#     919     handle_unknown=self.handle_unknown,
#     920     force_all_finite="allow-nan",
#     921     warn_on_unknown=warn_on_unknown,
#     922 )
#     923 self._map_infrequent_categories(X_int, X_mask)
#     925 n_samples, n_features = X_int.shape
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:174, in _BaseEncoder._transform(self, X, handle_unknown, force_all_finite, warn_on_unknown)
#     169 if handle_unknown == "error":
#     170     msg = (
#     171         "Found unknown categories {0} in column {1}"
#     172         " during transform".format(diff, i)
#     173     )
# --> 174     raise ValueError(msg)
#     175 else:
#     176     if warn_on_unknown:
#
# ValueError: Found unknown categories ['DNA-binding transcriptional regulator/c-di-GMP phosphodiesterase PdeL', 'YmaF family protein', 'excinuclease ABC subunit A', 'uncharacterized protein YebO', 'putative transposase', 'abortive infection system antitoxin AbiGi family protein', 'propionyl-CoA:succinate CoA transferase', 'D-arabinose 5-phosphate isomerase GutQ', '(deoxy)nucleoside triphosphate pyrophosphohydrolase', 'DNA-binding transcriptional dual regulator AsnC', 'putative adenosine monophosphate--protein transferase Fic', 'phage DNA ejection protein', 'electron transfer flavoprotein subunit alpha', 'CRISPR-associated endoribonuclease Cas2', 'tetrahydrofolate dehydrogenase/cyclohydrolase catalytic domain-containing protein', 'V-type ATP synthase subunit E', 'type IV secretion protein Rhs', 'V-type ATP synthase subunit B', 'phage minor tail protein G', 'hydroxyacylglutathione hydrolase GloC', '2-oxoglutaramate amidase', 'DUF1440 domain-containing inner membrane protein YagU', 'thiol-disulfide exchange protein DsbD', 'DUF896 family protein', 'putative GTP-binding protein YkfA', 'SinI family autotransporter-associated protein', 'DUF3165 family protein', 'cytochrome-c peroxidase', 'PTS system glucose-specific transporter subunit IIBC', 'stage V sporulation protein D', 'bifunctional S-methyl-5-thioribose-1-phosphate isomerase/methylthioribulose 1-phosphate dehydratase', 'cell shape determining protein MreD', 'DNA-binding transcriptional activator DcuR', 'secretion protein', 'PTS system fructose-specific transporter subunit IIABC', 'DUF3999 family protein', 'DUF1869 domain-containing protein YoaG', 'IS701-like element ISSav3 family transposase', 'RNA polymerase sporulation sigma factor SigE', 'SCO5918 family protein', 'glutamic-type intramembrane protease PrsW', 'phosphate butyryltransferase', '50S ribosomal subunit protein L24', 'nucleoid-associated protein SymE', 'DUF480 domain-containing protein', 'phosphatase domain-containing protein YnbD', 'PF02464 family protein YdeJ', 'argininosuccinate synthetase', 'hydroxymethylglutaryl-CoA synthase family protein', 'DUF5970 family protein', 'adenosine kinase', 'PF05406 family protein YehF', 'DUF6482 family protein', 'OsmC family peroxiredoxin', 'acryloyl-CoA reductase', 'copper ion binding protein', 'mannosyltransferase', 'sodium, sulfate symporter', 'anti-sigma factor antagonist BldG', 'hexitol phosphatase B', 'YqeG family HAD IIIA-type phosphatase', 'glycoside hydrolase family 36 protein', 'sigma-E processing peptidase SpoIIGA', 'putative kinase inhibitor', 'immunodominant antigen A', 'DUF951 domain-containing protein', 'RNB domain-containing ribonuclease', 'RNase I', 'DNA-binding/iron metalloprotein/AP endonuclease', 'DUF1444 domain-containing protein', 'uncharacterized protein YggT', 'hydrogenase 4 component C', 'DUF2591 domain-containing protein', "beta-carotene 15,15'-dioxygenase, Brp/Blh family", 'putative fimbrial protein YcbU', 'acetohydroxy acid synthase I subunit IlvN', 'phosphoribosylglycinamide formyltransferase 1', 'putative DNA-binding transcriptional regulator DicC', 'murein hydrolase regulator LrgA', 'putative enamine/imine deaminase', '6-pyruvoyl tetrahydropterin synthase', 'gpW family head-tail joining protein', 'FAD-I family protein', 'putative basic amino acid antiporter YfcC', 'nucleoside:H(+) symporter NupC', 'methyl-accepting chemotaxis protein Tar', 'opine metallophore biosynthesis dehydrogenase', 'aspartate semialdehyde dehydrogenase', 'DUF6636 domain-containing protein', 'para-aminobenzoate synthase glutamine amidotransferase component II', 'tRNA preQ1(34) S-adenosylmethionine ribosyltransferase-isomerase', 'ica operon transcriptional regulator IcaR', '16S rRNA m(3)U1498 methyltransferase', 'DUF2280 domain-containing protein', 'fibrinogen-binding protein SdrD', 'putative enzyme-specific chaperone YaaW', 'sugar phosphatase YbiV', 'uncharacterized protein YaeQ', 'DUF6113 family protein', 'EndoU domain-containing protein', 'putative HspQ acetyl donor', 'phi PV83 ...

# %%
sca = StandardScaler()
sca.fit_transform(X_train[num])
X_test[num] = sca.transform(X_test[num])

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
from sklearn.preprocessing import LabelEncoder
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import seaborn as sns
from keras.layers import Dense, BatchNormalization, Dropout, LSTM
from keras.models import Sequential
from keras.utils import to_categorical
from keras.optimizers import Adam
from tensorflow.keras import regularizers
from sklearn.metrics import precision_score, recall_score, confusion_matrix, classification_report, accuracy_score, f1_score
from keras import callbacks

np.random.seed(0)
# Out:
# 2024-06-03 18:53:12.440023: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-03 18:53:12.440199: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-03 18:53:12.650502: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
#Early stopping
early_stopping = callbacks.EarlyStopping(
    min_delta=0.001, # minimium amount of change to count as an improvement
    patience=20, # how many epochs to wait before stopping
    restore_best_weights=True,
)

# Initialising the NN
model = Sequential()

# layers

model.add(Dense(units = 32, kernel_initializer = 'uniform', activation = 'relu', input_dim = 26))
model.add(Dense(units = 32, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dense(units = 16, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dropout(0.25))
model.add(Dense(units = 8, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# Compiling the ANN
opt = Adam(learning_rate=0.00009)
model.compile(optimizer = opt, loss = 'binary_crossentropy', metrics = ['accuracy'])

# Train the ANN
history = model.fit(X_train, y_train, batch_size = 32, epochs = 150, callbacks=[early_stopping], validation_split=0.2)
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[85], line 26
#      23 model.compile(optimizer = opt, loss = 'binary_crossentropy', metrics = ['accuracy'])
#      25 # Train the ANN
# ---> 26 history = model.fit(X_train, y_train, batch_size = 32, epochs = 150, callbacks=[early_stopping], validation_split=0.2)
#
# File /opt/conda/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File /opt/conda/lib/python3.10/site-packages/optree/ops.py:594, in tree_map(func, tree, is_leaf, none_is_leaf, namespace, *rests)
#     592 leaves, treespec = _C.flatten(tree, is_leaf, none_is_leaf, namespace)
#     593 flat_args = [leaves] + [treespec.flatten_up_to(r) for r in rests]
# --> 594 return treespec.unflatten(map(func, *flat_args))
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/internals/managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
#     431     "astype",
#     432     dtype=dtype,
#     433     copy=copy,
#     434     errors=errors,
#     435     using_cow=using_copy_on_write(),
#     436 )
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/internals/managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/internals/blocks.py:758, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     755         raise ValueError("Can not squeeze with more than one column.")
#     756     values = values[0, :]  # type: ignore[call-overload]
# --> 758 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     760 new_values = maybe_coerce_values(new_values)
#     762 refs = None
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/dtypes/astype.py:237, in astype_array_safe(values, dtype, copy, errors)
#     234     dtype = dtype.numpy_dtype
#     236 try:
# --> 237     new_values = astype_array(values, dtype, copy=copy)
#     238 except (ValueError, TypeError):
#     239     # e.g. _astype_nansafe can fail on object-dtype of strings
#     240     #  trying to convert to float
#     241     if errors == "ignore":
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/dtypes/astype.py:182, in astype_array(values, dtype, copy)
#     179     values = values.astype(dtype, copy=copy)
#     181 else:
# --> 182     values = _astype_nansafe(values, dtype, copy=copy)
#     184 # in pandas we don't store numpy str dtypes, so convert to object
#     185 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/dtypes/astype.py:133, in _astype_nansafe(arr, dtype, copy, skipna)
#     129     raise ValueError(msg)
#     131 if copy or arr.dtype == object or dtype == object:
#     132     # Explicit copy, or required since NumPy can't view from / to object.
# --> 133     return arr.astype(dtype, copy=True)
#     135 return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: 'plus'

# %%
history_df = pd.DataFrame(history.history)

plt.plot(history_df.loc[:, ['loss']], "#BDE2E2", label='Training loss')
plt.plot(history_df.loc[:, ['val_loss']],"#C2C4E2", label='Validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc="best")

plt.show()

# %%
history_df = pd.DataFrame(history.history)

plt.plot(history_df.loc[:, ['accuracy']], "#BDE2E2", label='Training accuracy')
plt.plot(history_df.loc[:, ['val_accuracy']], "#C2C4E2", label='Validation accuracy')

plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
